# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

stat = pd.read_csv('kmeans_results.csv')
df = pd.DataFrame(stat)

plt.figure(figsize=(6,4))
plt.scatter(df['k3, x'], df['k3, y'], c = df['k3, pred'], s = 25)
plt.scatter(df['k3, centx'], df['k3, centy'], c = 'black', marker = '^' )
plt.text(40, 110, "K = 3", fontsize=12, bbox=dict(facecolor='white'))
plt.xlabel('PC1', fontdict = {'fontsize' : 19})
plt.ylabel('PC2',  fontdict = {'fontsize' : 19})

plt.savefig('PC1-PC2-K3_graph.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

stat = pd.read_csv('kmeans_results.csv')
df = pd.DataFrame(stat)

plt.figure(figsize=(6,4))
plt.scatter(df['k2, x'], df['k2, y'], c = df['k2, pred'], s = 25)
plt.scatter(df['k2, centx'], df['k2, centy'], c = 'black', marker = '^' )
plt.text(40, 110, "K = 2", fontsize=12, bbox=dict(facecolor='white'))
plt.xlabel('PC1', fontdict = {'fontsize' : 19})
plt.ylabel('PC2',  fontdict = {'fontsize' : 19})

plt.savefig('PC1-PC2-K2_graph.png')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['k4, x'], df['k4, y'], c = df['k4, pred'], s = 25)
plt.scatter(df['k4, centx'].dropna(), df['k4, centy'].dropna(), c = 'black', marker = '^', )
plt.text(40, 110, "K = 4", fontsize=12, bbox=dict(facecolor='white'))
plt.xlabel('PC1', fontdict = {'fontsize' : 19})
plt.ylabel('PC2',  fontdict = {'fontsize' : 19})
plt.savefig('PC1-PC2-K4_graph.png')

plt.show()

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['k5, x'], df['k5, y'], c = df['k5, pred'], s = 25)
plt.scatter(df['k5, centx'].dropna(), df['k5, centy'].dropna(), c = 'black', marker = '^', )
plt.text(40, 110, "K = 5", fontsize=12, bbox=dict(facecolor='white'))
plt.xlabel('PC1', fontdict = {'fontsize' : 19})
plt.ylabel('PC2',  fontdict = {'fontsize' : 19})
plt.savefig('PC1-PC2-K5_graph.png')

plt.show()

# %%
plt.figure(figsize = (4,4))
plt.plot(df['temperature'], df['k4, pred'].sort_values(ascending = False), marker = '.', label = 'K = 4', c = 'blue')
plt.xticks([0, 100, 200, 300, 400])
plt.yticks([0, 1, 2, 3])
plt.xlabel('Temperature', fontdict = {'fontsize' : 15})
plt.ylabel('Cluster label(c)', fontdict = {'fontsize' : 15})
plt.axvline(10, color='red', linestyle='--')
plt.axvline(200, color='red', linestyle='--')
plt.axvline(20, color='red', linestyle='--')
plt.axvline(30, color='red', linestyle='--')
plt.axvline(120, color='red', linestyle='--')
plt.axvline(130, color='red', linestyle='--')
plt.legend(loc = 'upper right')
plt.savefig('Temperature-cluster_label_graph_K4.png')
plt.show()

# %%
plt.figure(figsize = (4,4))
plt.plot(df['temperature'], df['k3, pred'].sort_values(ascending = False), marker = '.', label = 'K = 3', c = 'blue')
plt.xticks([0, 100, 200, 300, 400])
plt.yticks([0, 1, 2, 3])
plt.xlabel('Temperature', fontdict = {'fontsize' : 15})
plt.ylabel('Cluster label(c)', fontdict = {'fontsize' : 15})
plt.axvline(10, color='red', linestyle='--')
plt.axvline(20, color='red', linestyle='--')
plt.axvline(200, color='red', linestyle='--')
#plt.axvline(130, color='red', linestyle='--')
plt.legend(loc = 'upper right')
plt.savefig('Temperature-cluster_label_graph_K3.png')
plt.show()

# %%
plt.figure(figsize = (4,4))
plt.plot(df['temperature'], df['k5, pred'].sort_values(ascending = False), marker = '.', label = 'K = 5', c = 'blue')
plt.xticks([0, 100, 200, 300, 400])
plt.yticks([0, 1, 2, 3, 4])
plt.xlabel('Temperature', fontdict = {'fontsize' : 15})
plt.ylabel('Cluster label(c)', fontdict = {'fontsize' : 15})
plt.axvline(10, color='red', linestyle='--')
plt.axvline(20, color='red', linestyle='--')
plt.axvline(250, color='red', linestyle='--')
plt.axvline(260, color='red', linestyle='--')
plt.axvline(270, color='red', linestyle='--')
plt.axvline(280, color='red', linestyle='--')
plt.legend(loc = 'upper right')
plt.savefig('Temperature-cluster_label_graph_K5.png')
plt.show()

# %%
plt.figure(figsize = (4,4))
plt.plot(df['temperature'], df['k2, pred'].sort_values(ascending = False), marker = '.', label = 'K = 2', c = 'blue')
plt.xticks([0, 100, 200, 300, 400])
plt.yticks([0, 1, 2, 3])
plt.xlabel('Temperature', fontdict = {'fontsize' : 15})
plt.ylabel('Cluster label(c)', fontdict = {'fontsize' : 15})
plt.axvline(10, color='red', linestyle='--')
plt.axvline(180, color='red', linestyle='--')
plt.axvline(170, color='red', linestyle='--')
#plt.axvline(260, color='red', linestyle='--')
#plt.axvline(270, color='red', linestyle='--')
#plt.axvline(280, color='red', linestyle='--')
plt.legend(loc = 'upper right')
plt.savefig('Temperature-cluster_label_graph_K2.png')
plt.show()
